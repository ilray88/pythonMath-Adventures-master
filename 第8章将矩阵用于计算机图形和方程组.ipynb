# %% [markdown]
# ## 8.5画2D形状

# %%
from PIL import Image
from IPython.core.display import display
display(Image.open(r'D:\0ilraypan\git_jia\《用Python学数学》\martrices\1f.png'))
display(Image.open(r'D:\0ilraypan\git_jia\《用Python学数学》\martrices\2f.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=600x600 at 0x23E53F9D438>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=600x600 at 0x23E53F9D438>
