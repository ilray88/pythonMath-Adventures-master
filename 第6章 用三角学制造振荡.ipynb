# %% [markdown]
# ## sin(x)

# %%
from PIL import Image
from IPython.core.display import display
display(Image.open(r'D:\0ilraypan\git_jia\《用Python学数学》\sin_x_\image.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=600x600 at 0x232A734A438>

# %% [markdown]
# ## 6.3画正弦波

# %%
from PIL import Image
from IPython.core.display import display
display(Image.open(r'D:\0ilraypan\git_jia\《用Python学数学》\CircleSineWave\image.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=600x600 at 0x232A7618E48>

# %% [markdown]
# ## 6.4编写万花尺程序

# %%
from PIL import Image
from IPython.core.display import display
display(Image.open(r'D:\0ilraypan\git_jia\《用Python学数学》\Spirograph\image.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=600x600 at 0x232A7612630>

# %% [markdown]
# ## 6.5画谐波图

# %%
from PIL import Image
from IPython.core.display import display
display(Image.open(r'D:\0ilraypan\git_jia\《用Python学数学》\harmonograph\image.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=600x600 at 0x232A761F828>
